# %% [markdown]
# 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

# %%
# !pip install transformers datasets huggingface_hub

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from datasets import load_dataset, Dataset
from huggingface_hub import login

#  Login to Hugging Face
login("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")

print("1. Downloading Model and Tokenizer...")
tokenizer = AutoTokenizer.from_pretrained("ai4bharat/IndicBART")
model = AutoModelForSeq2SeqLM.from_pretrained("ai4bharat/IndicBART")

# Save them to a local folder
tokenizer.save_pretrained("./local_indicbart")
model.save_pretrained("./local_indicbart")
print(" Model saved to ./local_indicbart")

print("2. Downloading ONLY the Sanskrit BPCC Dataset...")

dataset_stream = load_dataset("ai4bharat/BPCC", "bpcc-seed-latest", split="san_Deva", streaming=True)

# Extract exactly the 22,000 rows over the network
print("Fetching 22,000 Sanskrit rows (this will be much faster)...")
subset_list = list(dataset_stream.take(22000))

# Convert the streamed list back into a standard local Hugging Face dataset format
subset = Dataset.from_list(subset_list)

# Save the pure Sanskrit dataset to a local folder
subset.save_to_disk("./local_bpcc_dataset")
print(" Dataset saved to ./local_bpcc_dataset")

print("\nALL DONE! Now copy the 'local_indicbart' and 'local_bpcc_dataset' folders to your offline GPU machine.")
# Out:
# ...
# 1. Downloading Model and Tokenizer...
# ...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Model saved to ./local_indicbart
# 2. Downloading ONLY the Sanskrit BPCC Dataset...
# Fetching 22,000 Sanskrit rows (this will be much faster)...
# Saving the dataset (0/1 shards):   0%|          | 0/22000 [00:00<?, ? examples/s]
# ✅ Dataset saved to ./local_bpcc_dataset
#
# 🎉 ALL DONE! Now copy the 'local_indicbart' and 'local_bpcc_dataset' folders to your offline GPU machine.

# %%
# !pip install evaluate sacrebleu rouge_score
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 35.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.6 MB/s  0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24988 sha256=bb1ae86d5c9f4941634edcb10dd61fdf3ef90fe486c1911dc9cbfddff6305e6c
#   Stored in directory: /home/aakash/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [evaluate]/10 [evaluate]re]
# ...
